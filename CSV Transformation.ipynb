# %% [markdown]
# # This notebook depicts how to convert the scraped data into a format that is much more usable

# %% [markdown]
# ## The format in which the data was scraped

# %%
import pandas as pd

df = pd.read_csv("financial_data.csv")
df
# Out:
#                                     Period Ending:  10/31/2022  10/31/2021  \
# 0                                    Total Revenue  $6,848,000  $6,319,000
# 1                                  Cost of Revenue  $3,126,000  $2,912,000
# 2                                     Gross Profit  $3,722,000  $3,407,000
# 3                               Operating Expenses         NaN         NaN
# 4                         Research and Development    $467,000    $441,000
# 5                        Sales, General and Admin.  $1,637,000  $1,619,000
# 6                              Non-Recurring Items          --          --
# 7                            Other Operating Items          --          --
# 8                                 Operating Income  $1,618,000  $1,347,000
# 9                       Add'l income/expense items    -$30,000     $94,000
# 10                Earnings Before Interest and Tax  $1,588,000  $1,441,000
# ...

# %%
df['Symbol'] = 'a'

df.set_index('Period Ending:', inplace=True)

df = df.T

df = df.reset_index()
df = df.rename(columns={'index': 'Date'})

df.reset_index(drop=True, inplace=True)
# Out:
# Period Ending:       index
# 0               10/31/2022
# 1               10/31/2021
# 2               10/31/2020
# 3               10/31/2019
# 4                   Symbol

# %%
df.columns
# Out:
# Index(['index', 'Total Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Research and Development',
#        'Sales, General and Admin.', 'Non-Recurring Items',
#        'Other Operating Items', 'Operating Income',
#        'Add'l income/expense items', 'Earnings Before Interest and Tax',
#        'Interest Expense', 'Earnings Before Tax', 'Income Tax',
#        'Minority Interest', 'Equity Earnings/Loss Unconsolidated Subsidiary',
#        'Net Income-Cont. Operations', 'Net Income',
#        'Net Income Applicable to Common Shareholders', 'Symbol'],
#       dtype='object', name='Period Ending:')

# %%
df
# Out:
# Period Ending:       index Total Revenue Cost of Revenue Gross Profit  \
# 0               10/31/2022    $6,848,000      $3,126,000   $3,722,000
# 1               10/31/2021    $6,319,000      $2,912,000   $3,407,000
# 2               10/31/2020    $5,339,000      $2,502,000   $2,837,000
# 3               10/31/2019    $5,163,000      $2,358,000   $2,805,000
# 4                   Symbol             a               a            a
#
# Period Ending: Operating Expenses Research and Development  \
# 0                             NaN                 $467,000
# 1                             NaN                 $441,000
# 2                             NaN                 $495,000
# 3                             NaN                 $404,000
# 4                               a                        a
#
# Period Ending: Sales, General and Admin. Non-Recurring Items  \
# 0                             $1,637,000                  --
# 1                             $1,619,000                  --
# ...

# %%
df = df.drop(4)

# %%
df
# Out:
# Period Ending:       index Total Revenue Cost of Revenue Gross Profit  \
# 0               10/31/2022    $6,848,000      $3,126,000   $3,722,000
# 1               10/31/2021    $6,319,000      $2,912,000   $3,407,000
# 2               10/31/2020    $5,339,000      $2,502,000   $2,837,000
# 3               10/31/2019    $5,163,000      $2,358,000   $2,805,000
#
# Period Ending: Operating Expenses Research and Development  \
# 0                             NaN                 $467,000
# 1                             NaN                 $441,000
# 2                             NaN                 $495,000
# 3                             NaN                 $404,000
#
# Period Ending: Sales, General and Admin. Non-Recurring Items  \
# 0                             $1,637,000                  --
# 1                             $1,619,000                  --
# 2                             $1,496,000                  --
# 3                             $1,460,000                  --
#
# ...

# %%
df = df.rename(columns={'index': 'Period Ending'})

# %%
df
# Out:
# Period Ending: Period Ending Total Revenue Cost of Revenue Gross Profit  \
# 0                 10/31/2022    $6,848,000      $3,126,000   $3,722,000
# 1                 10/31/2021    $6,319,000      $2,912,000   $3,407,000
# 2                 10/31/2020    $5,339,000      $2,502,000   $2,837,000
# 3                 10/31/2019    $5,163,000      $2,358,000   $2,805,000
#
# Period Ending: Operating Expenses Research and Development  \
# 0                             NaN                 $467,000
# 1                             NaN                 $441,000
# 2                             NaN                 $495,000
# 3                             NaN                 $404,000
#
# Period Ending: Sales, General and Admin. Non-Recurring Items  \
# 0                             $1,637,000                  --
# 1                             $1,619,000                  --
# 2                             $1,496,000                  --
# ...

# %%
df.to_csv('f_data.csv', index=False)

# %%
df = pd.read_csv("f_data.csv")
df
# Out:
#   Period Ending Total Revenue Cost of Revenue Gross Profit  \
# 0    10/31/2022    $6,848,000      $3,126,000   $3,722,000
# 1    10/31/2021    $6,319,000      $2,912,000   $3,407,000
# 2    10/31/2020    $5,339,000      $2,502,000   $2,837,000
# 3    10/31/2019    $5,163,000      $2,358,000   $2,805,000
#
#    Operating Expenses Research and Development Sales, General and Admin.  \
# 0                 NaN                 $467,000                $1,637,000
# 1                 NaN                 $441,000                $1,619,000
# 2                 NaN                 $495,000                $1,496,000
# 3                 NaN                 $404,000                $1,460,000
#
#   Non-Recurring Items Other Operating Items Operating Income  ...  \
# 0                  --                    --       $1,618,000  ...
# 1                  --                    --       $1,347,000  ...
# 2                  --                    --         $846,000  ...
# ...

# %%
df.drop(df.columns[-1], axis=1, inplace=True)

df['Symbol'] = 'a'

df = df[['Symbol'] + [col for col in df.columns if col != 'Symbol']]

df
# Out:
#   Symbol Period Ending Total Revenue Cost of Revenue Gross Profit  \
# 0      a    10/31/2022    $6,848,000      $3,126,000   $3,722,000
# 1      a    10/31/2021    $6,319,000      $2,912,000   $3,407,000
# 2      a    10/31/2020    $5,339,000      $2,502,000   $2,837,000
# 3      a    10/31/2019    $5,163,000      $2,358,000   $2,805,000
#
#    Operating Expenses Research and Development Sales, General and Admin.  \
# 0                 NaN                 $467,000                $1,637,000
# 1                 NaN                 $441,000                $1,619,000
# 2                 NaN                 $495,000                $1,496,000
# 3                 NaN                 $404,000                $1,460,000
#
#   Non-Recurring Items Other Operating Items  ... Add'l income/expense items  \
# 0                  --                    --  ...                   -$30,000
# 1                  --                    --  ...                    $94,000
# ...

# %%
df.to_csv('updated_data.csv', index=False)

# %%
data = pd.read_csv("financial_data.csv")
data
# Out:
#                                     Period Ending:  10/31/2022  10/31/2021  \
# 0                                    Total Revenue  $6,848,000  $6,319,000
# 1                                  Cost of Revenue  $3,126,000  $2,912,000
# 2                                     Gross Profit  $3,722,000  $3,407,000
# 3                               Operating Expenses         NaN         NaN
# 4                         Research and Development    $467,000    $441,000
# 5                        Sales, General and Admin.  $1,637,000  $1,619,000
# 6                              Non-Recurring Items          --          --
# 7                            Other Operating Items          --          --
# 8                                 Operating Income  $1,618,000  $1,347,000
# 9                       Add'l income/expense items    -$30,000     $94,000
# 10                Earnings Before Interest and Tax  $1,588,000  $1,441,000
# ...

# %% [markdown]
# ### The data is still scraped in the older format but the following code is implemented to extract the data in the desired format and append it to the final csv

# %%
num_columns = data.shape[1]
data_col=df.shape[1]
for i in range(1,num_columns):
    c1= data.iloc[:, i]   
    c1=c1.tolist()
    h1 = data.columns[i]
    nr=['a']
    nr.append(h1)
    nr.extend(c1)
    if(len(nr) != data_col):
        nr += ['--'] * (data_col - len(nr)) #if list items is lesser than the no. of columns in some cases, padding of 0's was done to match the num of cols.
    df.loc[len(df)] = nr
    nr.clear()
df
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_7436\4184031323.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df)] = nr
# C:\Users\dell\AppData\Local\Temp\ipykernel_7436\4184031323.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df)] = nr
# C:\Users\dell\AppData\Local\Temp\ipykernel_7436\4184031323.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df)] = nr
# ...

# %%
print(len(nr))
print(data_col)
print(x)
print(data_col-x)
print(data_col-len(nr))
# Out:
# 20
# 21
# 100
# -79
# 1

# %%
num_columns
# Out:
# 5

# %%
data_col
# Out:
# 21

# %%
len(nr)
# Out:
# 20

# %%
df.shape[1]
# Out:
# 21

# %%
import pandas as pd
df = pd.read_csv("updated_data.csv")

# %%
df.insert(0, 'index', range(len(df)))

df.reset_index(drop=False, inplace=True)

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3852\2484254889.py in ?()
# ----> 1 df.insert(0, 'index', range(len(df)))
#       2
#       3 df.reset_index(drop=False, inplace=True)
#       4
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4927                 "'self.flags.allows_duplicate_labels' is False."
#    4928             )
#    4929         if not allow_duplicates and column in self.columns:
#    4930             # Should this be a different kind of error??
# -> 4931             raise ValueError(f"cannot insert {column}, already exists")
#    4932         if not is_integer(loc):
#    4933             raise TypeError("loc must be int")
#    4934         # convert non stdlib ints to satisfy typing checks
#
# ...

# %%
df
# Out:
#        level_0  index Symbol Period Ending Total Revenue Cost of Revenue  \
# 0            0      0      a    10/31/2022   $6,848,000      $3,126,000
# 1            1      1      a    10/31/2021   $6,319,000      $2,912,000
# 2            2      2      a    10/31/2020   $5,339,000      $2,502,000
# 3            3      3      a    10/31/2019   $5,163,000      $2,358,000
# 4            4      4     aa    12/31/2022  $12,451,000     $10,212,000
# ...        ...    ...    ...           ...           ...             ...
# 25707    25707  25707   ZYME    Unnamed: 4           NaN             NaN
# 25708    25708  25708   ZYXI    12/31/2022     $158,167         $32,005
# 25709    25709  25709   ZYXI    12/31/2021     $130,301         $27,321
# 25710    25710  25710   ZYXI    12/31/2020      $80,122         $17,417
# 25711    25711  25711   ZYXI    12/31/2019      $45,472          $8,814
#
#       Gross Profit  Operating Expenses Research and Development  \
# ...

# %%
df = df.drop(columns=['level_0'], errors='ignore')

# %%
df
# Out:
#        index Symbol Period Ending Total Revenue Cost of Revenue Gross Profit  \
# 0          0      a    10/31/2022   $6,848,000      $3,126,000   $3,722,000
# 1          1      a    10/31/2021   $6,319,000      $2,912,000   $3,407,000
# 2          2      a    10/31/2020   $5,339,000      $2,502,000   $2,837,000
# 3          3      a    10/31/2019   $5,163,000      $2,358,000   $2,805,000
# 4          4     aa    12/31/2022  $12,451,000     $10,212,000   $2,239,000
# ...      ...    ...           ...           ...             ...          ...
# 25707  25707   ZYME    Unnamed: 4           NaN             NaN          NaN
# 25708  25708   ZYXI    12/31/2022     $158,167         $32,005     $126,162
# 25709  25709   ZYXI    12/31/2021     $130,301         $27,321     $102,980
# 25710  25710   ZYXI    12/31/2020      $80,122         $17,417      $62,705
# 25711  25711   ZYXI    12/31/2019      $45,472          $8,814      $36,658
#
# ...
